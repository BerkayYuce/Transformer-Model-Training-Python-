# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive"
# Out:
# 'Colab Notebooks'   DATASET   DDATA_SET   SPLIT_DATASET

# %%
# !ls "/content/drive/My Drive/SPLIT_DATASET/train"
# Out:
#  KIFOZ	'PEKTUS EKSKAVATUM'  'PEKTUS KARINATUM'  'POLAND SENDROMU'   SKOLYOZ

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

# %%
# Veri kümelerini ayırmak için klasörleri ve yolları tanımlayın
input_dir = '/content/drive/My Drive/Split_DATASET/train'
output_dir = '/content/drive/My Drive/SPLIT_DATASET'

test_size = 0.2  # %20 test, %80 eğitim

for class_name in os.listdir(input_dir):
    class_path = os.path.join(input_dir, class_name)

    if os.path.isdir(class_path):
        images = os.listdir(class_path)

        if len(images) == 0:
            print(f"{class_name} klasörü boş, işlem atlanıyor.")
            continue

        train_images, test_images = train_test_split(images, test_size=test_size, random_state=42)

        train_dir = os.path.join(output_dir, 'train', class_name)
        os.makedirs(train_dir, exist_ok=True)

        test_dir = os.path.join(output_dir, 'test', class_name)
        os.makedirs(test_dir, exist_ok=True)

        for img in train_images:
            try:
                shutil.copy(os.path.join(class_path, img), os.path.join(train_dir, img))
            except Exception as e:
                print(f"{img} dosyası kopyalanırken hata oluştu: {e}")

        for img in test_images:
            try:
                shutil.copy(os.path.join(class_path, img), os.path.join(test_dir, img))
            except Exception as e:
                print(f"{img} dosyası kopyalanırken hata oluştu: {e}")

print("Eğitim ve test kümeleri başarıyla ayrıldı!")
# Out:
# kifoz_2099.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2099.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2099.jpg' are the same file
# kifoz_4170.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4170.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4170.jpg' are the same file
# kifoz_4807.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4807.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4807.jpg' are the same file
# kifoz_3292.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3292.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3292.jpg' are the same file
# kifoz_3322.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3322.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3322.jpg' are the same file
# kifoz_1196.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1196.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1196.jpg' are the same file
# kifoz_2614.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2614.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2614.jpg' are the same file
# kifoz_152.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_152.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_152.jpg' are the same file
# kifoz_3673.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3673.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3673.jpg' are the same file
# kifoz_4321.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4321.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4321.jpg' are the same file
# kifoz_2392.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2392.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2392.jpg' are the same file
# kifoz_1947.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1947.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1947.jpg' are the same file
# kifoz_3330.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3330.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3330.jpg' are the same file
# kifoz_2979.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2979.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2979.jpg' are the same file
# kifoz_3603.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3603.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3603.jpg' are the same file
# kifoz_1587.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1587.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1587.jpg' are the same file
# kifoz_3739.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3739.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3739.jpg' are the same file
# kifoz_413.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_413.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_413.jpg' are the same file
# kifoz_4202.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4202.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4202.jpg' are the same file
# kifoz_353.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_353.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_353.jpg' are the same file
# kifoz_292.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_292.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_292.jpg' are the same file
# kifoz_1624.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1624.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1624.jpg' are the same file
# kifoz_3231.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3231.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3231.jpg' are the same file
# kifoz_1474.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1474.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1474.jpg' are the same file
# kifoz_4316.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4316.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4316.jpg' are the same file
# kifoz_4796.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4796.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4796.jpg' are the same file
# kifoz_2770.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2770.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2770.jpg' are the same file
# kifoz_420.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_420.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_420.jpg' are the same file
# kifoz_2108.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2108.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2108.jpg' are the same file
# kifoz_3649.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3649.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3649.jpg' are the same file
# kifoz_3432.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3432.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3432.jpg' are the same file
# kifoz_2816.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2816.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2816.jpg' are the same file
# kifoz_1133.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1133.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1133.jpg' are the same file
# kifoz_1106.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1106.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1106.jpg' are the same file
# kifoz_108.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_108.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_108.jpg' are the same file
# kifoz_2029.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2029.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2029.jpg' are the same file
# kifoz_4702.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4702.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4702.jpg' are the same file
# kifoz_1396.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1396.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1396.jpg' are the same file
# kifoz_258.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_258.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_258.jpg' are the same file
# kifoz_4713.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4713.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4713.jpg' are the same file
# kifoz_4192.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4192.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4192.jpg' are the same file
# kifoz_98.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_98.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_98.jpg' are the same file
# kifoz_4898.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4898.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4898.jpg' are the same file
# kifoz_675.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_675.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_675.jpg' are the same file
# kifoz_2353.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2353.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2353.jpg' are the same file
# kifoz_898.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_898.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_898.jpg' are the same file
# kifoz_4981.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4981.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4981.jpg' are the same file
# kifoz_3588.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3588.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3588.jpg' are the same file
# kifoz_2935.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2935.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2935.jpg' are the same file
# kifoz_8.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_8.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_8.jpg' are the same file
# kifoz_2399.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2399.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2399.jpg' are the same file
# kifoz_2755.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2755.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2755.jpg' are the same file
# kifoz_3022.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3022.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3022.jpg' are the same file
# kifoz_1197.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1197.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1197.jpg' are the same file
# kifoz_2228.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2228.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2228.jpg' are the same file
# kifoz_4250.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4250.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4250.jpg' are the same file
# kifoz_4348.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4348.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4348.jpg' are the same file
# kifoz_2449.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2449.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2449.jpg' are the same file
# kifoz_1094.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1094.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1094.jpg' are the same file
# kifoz_1912.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1912.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1912.jpg' are the same file
# kifoz_1790.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1790.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1790.jpg' are the same file
# kifoz_1730.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1730.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1730.jpg' are the same file
# kifoz_4149.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4149.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4149.jpg' are the same file
# kifoz_3842.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3842.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3842.jpg' are the same file
# kifoz_2548.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2548.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2548.jpg' are the same file
# kifoz_2667.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2667.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2667.jpg' are the same file
# kifoz_2694.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2694.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2694.jpg' are the same file
# kifoz_3128.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3128.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3128.jpg' are the same file
# kifoz_3004.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3004.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3004.jpg' are the same file
# kifoz_4248.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4248.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4248.jpg' are the same file
# kifoz_96.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_96.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_96.jpg' are the same file
# kifoz_766.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_766.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_766.jpg' are the same file
# kifoz_3417.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3417.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3417.jpg' are the same file
# kifoz_4525.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4525.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4525.jpg' are the same file
# kifoz_538.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_538.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_538.jpg' are the same file
# kifoz_1652.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1652.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1652.jpg' are the same file
# kifoz_1356.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1356.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1356.jpg' are the same file
# kifoz_1328.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1328.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1328.jpg' are the same file
# kifoz_4340.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4340.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4340.jpg' are the same file
# kifoz_3364.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3364.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3364.jpg' are the same file
# kifoz_4510.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4510.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4510.jpg' are the same file
# kifoz_171.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_171.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_171.jpg' are the same file
# kifoz_4163.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4163.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4163.jpg' are the same file
# kifoz_660.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_660.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_660.jpg' are the same file
# kifoz_2361.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2361.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2361.jpg' are the same file
# kifoz_1939.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1939.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1939.jpg' are the same file
# kifoz_303.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_303.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_303.jpg' are the same file
# kifoz_589.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_589.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_589.jpg' are the same file
# kifoz_1692.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1692.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1692.jpg' are the same file
# kifoz_4561.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4561.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4561.jpg' are the same file
# kifoz_2300.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2300.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2300.jpg' are the same file
# kifoz_1320.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1320.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1320.jpg' are the same file
# kifoz_460.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_460.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_460.jpg' are the same file
# kifoz_2313.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2313.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2313.jpg' are the same file
# kifoz_144.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_144.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_144.jpg' are the same file
# kifoz_997.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_997.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_997.jpg' are the same file
# kifoz_1199.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1199.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1199.jpg' are the same file
# kifoz_2472.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2472.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2472.jpg' are the same file
# kifoz_1067.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1067.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1067.jpg' are the same file
# kifoz_1428.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1428.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1428.jpg' are the same file
# kifoz_4142.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4142.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4142.jpg' are the same file
# kifoz_398.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_398.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_398.jpg' are the same file
# kifoz_4614.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4614.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4614.jpg' are the same file
# kifoz_2851.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2851.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2851.jpg' are the same file
# kifoz_818.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_818.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_818.jpg' are the same file
# kifoz_3539.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3539.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3539.jpg' are the same file
# kifoz_2425.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2425.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2425.jpg' are the same file
# kifoz_3962.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3962.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3962.jpg' are the same file
# kifoz_880.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_880.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_880.jpg' are the same file
# kifoz_4132.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4132.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4132.jpg' are the same file
# kifoz_106.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_106.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_106.jpg' are the same file
# kifoz_902.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_902.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_902.jpg' are the same file
# kifoz_2760.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2760.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2760.jpg' are the same file
# kifoz_4643.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4643.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4643.jpg' are the same file
# kifoz_2794.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2794.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2794.jpg' are the same file
# kifoz_1298.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1298.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1298.jpg' are the same file
# kifoz_2071.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2071.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2071.jpg' are the same file
# kifoz_4232.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4232.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4232.jpg' are the same file
# kifoz_1779.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1779.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1779.jpg' are the same file
# kifoz_4324.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4324.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4324.jpg' are the same file
# kifoz_1878.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1878.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1878.jpg' are the same file
# kifoz_2924.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2924.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2924.jpg' are the same file
# kifoz_2440.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2440.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2440.jpg' are the same file
# kifoz_2358.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2358.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2358.jpg' are the same file
# kifoz_197.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_197.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_197.jpg' are the same file
# kifoz_799.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_799.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_799.jpg' are the same file
# kifoz_4042.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4042.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4042.jpg' are the same file
# kifoz_1638.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1638.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1638.jpg' are the same file
# kifoz_4649.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4649.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4649.jpg' are the same file
# kifoz_60.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_60.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_60.jpg' are the same file
# kifoz_396.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_396.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_396.jpg' are the same file
# kifoz_3418.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3418.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3418.jpg' are the same file
# kifoz_4187.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4187.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4187.jpg' are the same file
# kifoz_1865.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1865.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1865.jpg' are the same file
# kifoz_3812.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3812.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3812.jpg' are the same file
# kifoz_2584.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2584.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2584.jpg' are the same file
# kifoz_2252.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2252.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2252.jpg' are the same file
# kifoz_4298.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4298.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4298.jpg' are the same file
# kifoz_1074.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1074.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1074.jpg' are the same file
# kifoz_3531.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3531.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3531.jpg' are the same file
# kifoz_1564.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1564.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1564.jpg' are the same file
# kifoz_4152.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4152.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4152.jpg' are the same file
# kifoz_1188.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1188.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1188.jpg' are the same file
# kifoz_4584.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4584.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4584.jpg' are the same file
# kifoz_1696.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1696.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1696.jpg' are the same file
# kifoz_1345.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1345.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1345.jpg' are the same file
# kifoz_4694.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4694.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4694.jpg' are the same file
# kifoz_5016.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_5016.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_5016.jpg' are the same file
# kifoz_2367.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2367.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2367.jpg' are the same file
# kifoz_2161.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2161.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2161.jpg' are the same file
# kifoz_653.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_653.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_653.jpg' are the same file
# kifoz_1111.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1111.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1111.jpg' are the same file
# kifoz_3357.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3357.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3357.jpg' are the same file
# kifoz_587.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_587.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_587.jpg' are the same file
# kifoz_2418.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2418.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2418.jpg' are the same file
# kifoz_1775.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1775.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1775.jpg' are the same file
# kifoz_2594.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2594.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2594.jpg' are the same file
# kifoz_2822.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2822.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2822.jpg' are the same file
# kifoz_343.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_343.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_343.jpg' are the same file
# kifoz_4415.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4415.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4415.jpg' are the same file
# kifoz_1403.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1403.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1403.jpg' are the same file
# kifoz_3130.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3130.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3130.jpg' are the same file
# kifoz_4307.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4307.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4307.jpg' are the same file
# kifoz_4244.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4244.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4244.jpg' are the same file
# kifoz_3486.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3486.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3486.jpg' are the same file
# kifoz_3750.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3750.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3750.jpg' are the same file
# kifoz_3335.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3335.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3335.jpg' are the same file
# kifoz_2853.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2853.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2853.jpg' are the same file
# kifoz_2219.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2219.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2219.jpg' are the same file
# kifoz_4918.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4918.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4918.jpg' are the same file
# kifoz_862.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_862.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_862.jpg' are the same file
# kifoz_1579.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1579.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1579.jpg' are the same file
# kifoz_986.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_986.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_986.jpg' are the same file
# kifoz_3042.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3042.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3042.jpg' are the same file
# kifoz_1406.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1406.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1406.jpg' are the same file
# kifoz_4230.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4230.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4230.jpg' are the same file
# kifoz_2727.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2727.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2727.jpg' are the same file
# kifoz_1387.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1387.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1387.jpg' are the same file
# kifoz_1596.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1596.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1596.jpg' are the same file
# kifoz_2371.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2371.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2371.jpg' are the same file
# kifoz_2354.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2354.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2354.jpg' are the same file
# kifoz_1268.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1268.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1268.jpg' are the same file
# kifoz_820.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_820.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_820.jpg' are the same file
# kifoz_2426.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2426.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2426.jpg' are the same file
# kifoz_3544.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3544.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3544.jpg' are the same file
# kifoz_2433.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2433.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2433.jpg' are the same file
# kifoz_1091.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1091.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1091.jpg' are the same file
# kifoz_3393.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3393.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3393.jpg' are the same file
# kifoz_2753.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2753.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2753.jpg' are the same file
# kifoz_4028.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4028.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4028.jpg' are the same file
# kifoz_2828.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2828.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2828.jpg' are the same file
# kifoz_3181.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3181.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3181.jpg' are the same file
# kifoz_3888.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3888.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3888.jpg' are the same file
# kifoz_4826.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4826.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4826.jpg' are the same file
# kifoz_399.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_399.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_399.jpg' are the same file
# kifoz_4049.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4049.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4049.jpg' are the same file
# kifoz_2880.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2880.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2880.jpg' are the same file
# kifoz_4325.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4325.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4325.jpg' are the same file
# kifoz_4771.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4771.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4771.jpg' are the same file
# kifoz_75.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_75.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_75.jpg' are the same file
# kifoz_1592.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1592.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1592.jpg' are the same file
# kifoz_4395.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4395.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4395.jpg' are the same file
# kifoz_3622.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3622.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3622.jpg' are the same file
# kifoz_2403.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2403.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2403.jpg' are the same file
# kifoz_212.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_212.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_212.jpg' are the same file
# kifoz_536.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_536.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_536.jpg' are the same file
# kifoz_1028.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1028.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1028.jpg' are the same file
# kifoz_739.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_739.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_739.jpg' are the same file
# kifoz_296.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_296.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_296.jpg' are the same file
# kifoz_4797.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4797.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4797.jpg' are the same file
# kifoz_913.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_913.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_913.jpg' are the same file
# kifoz_3519.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3519.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3519.jpg' are the same file
# kifoz_2234.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2234.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2234.jpg' are the same file
# kifoz_5008.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_5008.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_5008.jpg' are the same file
# kifoz_4953.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4953.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4953.jpg' are the same file
# kifoz_629.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_629.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_629.jpg' are the same file
# kifoz_2502.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2502.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2502.jpg' are the same file
# kifoz_1992.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1992.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1992.jpg' are the same file
# kifoz_3532.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3532.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3532.jpg' are the same file
# kifoz_3589.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3589.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3589.jpg' are the same file
# kifoz_2747.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2747.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2747.jpg' are the same file
# kifoz_4234.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4234.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4234.jpg' are the same file
# kifoz_331.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_331.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_331.jpg' are the same file
# kifoz_4734.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4734.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4734.jpg' are the same file
# kifoz_1601.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1601.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1601.jpg' are the same file
# kifoz_1457.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1457.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1457.jpg' are the same file
# kifoz_1714.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1714.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1714.jpg' are the same file
# kifoz_3795.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3795.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3795.jpg' are the same file
# kifoz_1976.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1976.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1976.jpg' are the same file
# kifoz_1463.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1463.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1463.jpg' are the same file
# kifoz_1810.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1810.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1810.jpg' are the same file
# kifoz_239.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_239.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_239.jpg' are the same file
# kifoz_1856.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1856.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1856.jpg' are the same file
# ...
# kifoz_4802.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4802.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4802.jpg' are the same file
# kifoz_1598.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1598.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1598.jpg' are the same file
# kifoz_4066.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4066.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4066.jpg' are the same file
# kifoz_3637.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3637.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3637.jpg' are the same file
# kifoz_216.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_216.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_216.jpg' are the same file
# kifoz_407.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_407.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_407.jpg' are the same file
# kifoz_1150.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1150.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1150.jpg' are the same file
# kifoz_3457.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3457.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3457.jpg' are the same file
# kifoz_50.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_50.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_50.jpg' are the same file
# kifoz_3594.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3594.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3594.jpg' are the same file
# kifoz_4446.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4446.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4446.jpg' are the same file
# kifoz_2223.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2223.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2223.jpg' are the same file
# kifoz_644.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_644.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_644.jpg' are the same file
# kifoz_1510.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1510.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1510.jpg' are the same file
# kifoz_3638.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3638.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3638.jpg' are the same file
# kifoz_4438.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4438.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4438.jpg' are the same file
# kifoz_66.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_66.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_66.jpg' are the same file
# kifoz_4322.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4322.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4322.jpg' are the same file
# kifoz_297.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_297.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_297.jpg' are the same file
# kifoz_912.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_912.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_912.jpg' are the same file
# kifoz_4311.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4311.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4311.jpg' are the same file
# kifoz_1257.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1257.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1257.jpg' are the same file
# kifoz_3712.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3712.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3712.jpg' are the same file
# kifoz_4769.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4769.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4769.jpg' are the same file
# kifoz_2326.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2326.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2326.jpg' are the same file
# kifoz_1645.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1645.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1645.jpg' are the same file
# kifoz_1574.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1574.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1574.jpg' are the same file
# kifoz_4943.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4943.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4943.jpg' are the same file
# kifoz_2528.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2528.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2528.jpg' are the same file
# kifoz_1099.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1099.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1099.jpg' are the same file
# kifoz_143.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_143.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_143.jpg' are the same file
# kifoz_2129.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2129.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2129.jpg' are the same file
# kifoz_2265.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2265.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2265.jpg' are the same file
# kifoz_4199.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4199.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4199.jpg' are the same file
# kifoz_3860.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3860.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3860.jpg' are the same file
# kifoz_79.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_79.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_79.jpg' are the same file
# kifoz_1523.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1523.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1523.jpg' are the same file
# kifoz_2415.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2415.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2415.jpg' are the same file
# kifoz_2678.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2678.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2678.jpg' are the same file
# kifoz_4647.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4647.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4647.jpg' are the same file
# kifoz_1424.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1424.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1424.jpg' are the same file
# kifoz_1087.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1087.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1087.jpg' are the same file
# kifoz_3922.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3922.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3922.jpg' are the same file
# kifoz_2320.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2320.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2320.jpg' are the same file
# kifoz_1439.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1439.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1439.jpg' are the same file
# kifoz_2477.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2477.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2477.jpg' are the same file
# kifoz_1385.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1385.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1385.jpg' are the same file
# kifoz_4474.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4474.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4474.jpg' are the same file
# kifoz_930.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_930.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_930.jpg' are the same file
# kifoz_19.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_19.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_19.jpg' are the same file
# kifoz_2763.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2763.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2763.jpg' are the same file
# kifoz_3360.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3360.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3360.jpg' are the same file
# kifoz_1488.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1488.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1488.jpg' are the same file
# kifoz_3676.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3676.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3676.jpg' are the same file
# kifoz_1304.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1304.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1304.jpg' are the same file
# kifoz_3495.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3495.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3495.jpg' are the same file
# kifoz_379.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_379.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_379.jpg' are the same file
# kifoz_4271.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4271.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4271.jpg' are the same file
# kifoz_373.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_373.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_373.jpg' are the same file
# kifoz_5018.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_5018.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_5018.jpg' are the same file
# kifoz_4498.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4498.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4498.jpg' are the same file
# kifoz_4411.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4411.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4411.jpg' are the same file
# kifoz_648.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_648.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_648.jpg' are the same file
# kifoz_408.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_408.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_408.jpg' are the same file
# kifoz_1653.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1653.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1653.jpg' are the same file
# kifoz_1160.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1160.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1160.jpg' are the same file
# kifoz_4824.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4824.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4824.jpg' are the same file
# kifoz_4638.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4638.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4638.jpg' are the same file
# kifoz_504.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_504.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_504.jpg' are the same file
# kifoz_2603.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2603.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2603.jpg' are the same file
# kifoz_3256.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3256.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3256.jpg' are the same file
# kifoz_1721.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1721.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1721.jpg' are the same file
# kifoz_2462.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2462.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_2462.jpg' are the same file
# kifoz_1792.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1792.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_1792.jpg' are the same file
# kifoz_4376.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4376.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_4376.jpg' are the same file
# kifoz_941.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_941.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_941.jpg' are the same file
# kifoz_3014.jpg dosyası kopyalanırken hata oluştu: '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3014.jpg' and '/content/drive/My Drive/SPLIT_DATASET/train/KIFOZ/kifoz_3014.jpg' are the same file

# %%
categories = ['KIFOZ', 'PEKTUS EKSKAVATUM', 'PEKTUS KARINATUM', 'POLAND SENDROMU', 'SKOLYOZ']
base_path = "/content/drive/My Drive/SPLIT_DATASET/"

total_train_count = 0
total_test_count = 0

for category in categories:
    train_path = os.path.join(base_path, 'train', category)
    test_path = os.path.join(base_path, 'test', category)

    train_count = len([f for f in os.listdir(train_path) if f.endswith(('jpg', 'jpeg', 'png'))]) if os.path.exists(train_path) else 0
    test_count = len([f for f in os.listdir(test_path) if f.endswith(('jpg', 'jpeg', 'png'))]) if os.path.exists(test_path) else 0

    total_train_count += train_count
    total_test_count += test_count

    print(f"{category}: Eğitim seti: {train_count} görüntü, Test seti: {test_count} görüntü")

print(f"\nToplam Eğitim görüntü sayısı: {total_train_count}")
print(f"Toplam Test görüntü sayısı: {total_test_count}")
print(f"Toplam Görüntü Sayısı: {total_train_count + total_test_count}")

# %%
categories = ['kifoz', 'pektus ekskavatum', 'pektus karinatum', 'poland sendromu', 'skolyoz']
base_path = "/content/drive/My Drive/Split_VeriSeti/"

total_train_count = 0
total_test_count = 0

for category in categories:
    train_path = os.path.join(base_path, 'train', category)
    test_path = os.path.join(base_path, 'test', category)

    train_count = len([f for f in os.listdir(train_path) if f.endswith(('jpg', 'jpeg', 'png'))]) if os.path.exists(train_path) else 0
    test_count = len([f for f in os.listdir(test_path) if f.endswith(('jpg', 'jpeg', 'png'))]) if os.path.exists(test_path) else 0

    total_train_count += train_count
    total_test_count += test_count

    print(f"{category}: Eğitim seti: {train_count} görüntü, Test seti: {test_count} görüntü")

print(f"\nToplam Eğitim görüntü sayısı: {total_train_count}")
print(f"Toplam Test görüntü sayısı: {total_test_count}")
print(f"Toplam Görüntü Sayısı: {total_train_count + total_test_count}")
